# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import seaborn as sns

# %%
df = pd.read_csv('microsoft_stock.csv', sep=',')
df.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060274  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062427   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063504   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061889    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060812    47894400
# 5  1986-03-20  0.098090  0.098090  0.094618  0.095486   0.059198    58435200
# 6  1986-03-21  0.095486  0.097222  0.091146  0.092882   0.057583    59990400
# 7  1986-03-24  0.092882  0.092882  0.089410  0.090278   0.055969    65289600
# 8  1986-03-25  0.090278  0.092014  0.089410  0.092014   0.057045    32083200
# 9  1986-03-26  0.092014  0.095486  0.091146  0.094618   0.058660    22752000

# %%
sns.set(rc={'figure.figsize':(20,8)}, style='whitegrid')
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
import datetime

def str_to_datetime(s):
    split = s.split('-')
    year, month, day = int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

df['Date'] = df['Date'].apply(str_to_datetime)
df.index = df.pop('Date')

# %%
sns.set(rc={'figure.figsize':(8,8)})
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler

mmx_scaler = MinMaxScaler(feature_range=(0,1))
data_normalized = mmx_scaler.fit_transform(df)
print(data_normalized)
# Out:
# [[0.00000000e+00 2.48537267e-05 0.00000000e+00 1.81490417e-05
#   1.12506652e-05 1.00000000e+00]
#  [2.26235223e-05 2.71129198e-05 2.29586226e-05 2.72235625e-05
#   1.68773044e-05 2.97096179e-01]
#  [3.16729312e-05 2.93721129e-05 3.21420716e-05 3.17634365e-05
#   1.96919308e-05 1.27119118e-01]
#  ...
#  [9.79774337e-01 9.81416357e-01 9.87621406e-01 9.82593221e-01
#   9.82594782e-01 1.59487542e-02]
#  [9.74196609e-01 9.78136857e-01 9.69873381e-01 9.69080721e-01
#   9.69083494e-01 2.22971723e-02]
#  [9.61555651e-01 9.71265620e-01 9.74475741e-01 9.68375070e-01
#   9.68377906e-01 2.01595983e-02]]
